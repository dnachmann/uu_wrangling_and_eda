# %%
import pandas as pd
import numpy as np
df = pd.read_csv('ForeignGifts_edu.csv')

# %%
uva_stats = df.loc[df['Institution Name'] == 'University of Virginia']
umich_stats = df.loc[df['Institution Name'] == 'University of Michigan - Ann Arbor']
uiuc_stats = df.loc[df['Institution Name'] == 'University of Illinois at Urbana-Champaign']
umd_stats = df.loc[df['Institution Name'] == 'University of Maryland, College Park']
ucla_stats = df.loc[df['Institution Name'] == 'University of California, Los Angeles']
utaustin_stats = df.loc[df['Institution Name'] == 'University of Texas at Austin']
unc_stats = df.loc[df['Institution Name'] == 'University of North Carolina - Chapel Hill']
ucberkeley_stats = df.loc[df['Institution Name'] == 'University of California, Berkeley']
uwmadison_stats = df.loc[df['Institution Name'] == 'University of Wisconsin - Madison']
uf_stats = df.loc[df['Institution Name'] == 'University of Florida']

# %%
unis = ['University of Virginia',
    'University of Michigan - Ann Arbor',
    'University of Illinois at Urbana-Champaign',
    'University of Maryland, College Park',
    'University of California, Los Angeles',
    'University of Texas at Austin',
    'University of North Carolina - Chapel Hill',
    'University of California, Berkeley',
    'University of Wisconsin - Madison',
    'University of Florida']
uni_stats = df[df['Institution Name'].isin(unis)]
uni_stats_group = uni_stats.groupby('Institution Name')
uni_stats_group['Foreign Gift Amount'].describe().sort_values(by = 'count', ascending = False)
# Out:
#                                              count           mean  \
# Institution Name
# University of California, Los Angeles       3916.0   61835.128447
# University of Michigan - Ann Arbor           715.0  401869.626573
# University of California, Berkeley           394.0  747410.923858
# University of Texas at Austin                377.0  227741.135279
# University of North Carolina - Chapel Hill   286.0  144379.524476
# University of Illinois at Urbana-Champaign   186.0  555653.440860
# University of Virginia                        98.0  226420.795918
# University of Maryland, College Park          86.0  348061.372093
# University of Wisconsin - Madison             38.0  603835.815789
# University of Florida                         33.0  750276.939394
#
#                                                      std       min       25%  \
# Institution Name
# University of California, Los Angeles       5.064669e+05       1.0      50.0
# University of Michigan - Ann Arbor          7.403600e+05     200.0  132398.0
# University of California, Berkeley          1.002672e+06     250.0  277125.5
# University of Texas at Austin               3.230952e+05     200.0   50000.0
# University of North Carolina - Chapel Hill  3.298919e+05       1.0    6008.5
# University of Illinois at Urbana-Champaign  1.537570e+06       3.0   91849.0
# University of Virginia                      3.433051e+05      31.0    9450.0
# University of Maryland, College Park        6.418397e+05   18187.0   81961.0
# University of Wisconsin - Madison           5.865185e+05  257917.0  300000.0
# University of Florida                       6.820767e+05  250000.0  343790.0
#
#                                                  50%        75%         max
# Institution Name
# University of California, Los Angeles          250.0    9605.00  25000000.0
# University of Michigan - Ann Arbor          200000.0  377213.00  10000000.0
# University of California, Berkeley          424025.0  708279.50   8083333.0
# University of Texas at Austin                97911.0  315347.00   2988896.0
# University of North Carolina - Chapel Hill   33548.0  135108.00   3340675.0
# University of Illinois at Urbana-Champaign  300000.0  533629.00  19500000.0
# University of Virginia                       80535.5  276888.25   1708021.0
# University of Maryland, College Park        194287.5  392313.25   5602522.0
# University of Wisconsin - Madison           379256.5  608183.25   3000000.0
# University of Florida                       483216.0  712412.00   3000628.0

# %% [markdown]
# Compared to similar universities, the University of Virginia has fewer total donations than average and a lower donation amount for both the mean and median donation. Additionally, it is last among these universities in largest donation. To fix this lack of foreign gifting, I propose expanding the donor base in locations UVA already receives donations from. Currently, UVA's top giftors by number of donations are from England, Sweden, Israel, and Bangladesh. Of those four, Bangladesh, Sweden, and England are the three largest donators by monetary value. The University should not make aiming for more large donations from Tanzania or Switzerland its primary goal, as those donations are infrequent and volatile compared to the smaller recurrent donations from Bangladesh, Sweden, and England. By expanding its donor frequency in these countries, the slow and steady gains will outpace the infrequent large donations offered by others. Average donations from Bangladesh, Sweden, and England total $890,000. While less than averages from countries with large, infrequent donations,these countries show more potential for growth. Assuming UVA runs an aggressive donation campaign where these three countries contribute 3 times for each contribution from Tanzania and Switzerland and all countries contribute 1.5x their donation, the total from smaller donations would overtake the larger ones in 3 donations as shown by the math below.

# %%
uva_giftors = uva_stats.groupby('Country of Giftor')
print(f'{uva_giftors['Foreign Gift Amount'].count()}\n')
print(f'{uva_giftors['Foreign Gift Amount'].sum().sort_values(ascending = False)}\n')
average_uva_donos = uva_giftors['Foreign Gift Amount'].sum() / uva_giftors['Foreign Gift Amount'].count()
print(f'{average_uva_donos.sort_values(ascending=False)}\n')
small_cycle_1 = sum((422858.900000, 402500.000000, 62924.709677)) + (sum((422858.900000, 402500.000000, 62924.709677)) * 1.5)
small_cycle_2 = (small_cycle_1) + (sum((422858.900000, 402500.000000, 62924.709677)) * 1.5)
small_cycle_3 = small_cycle_2 + (sum((422858.900000, 402500.000000, 62924.709677)) * 1.5)
print(f'{small_cycle_3}\n')
large_cycle = sum((1000000.000000, 925482.333333)) + (sum((1000000.000000, 925482.333333)) * 1.5)
print(f'{large_cycle}\n')
# Out:
# Country of Giftor
# BANGLADESH         10
# BERMUDA             1
# ENGLAND            31
# FINLAND             7
# FRANCE              5
# GUERNSEY            3
# ISRAEL             12
# JAPAN               1
# KOREA               6
# RWANDA              1
# SINGAPORE           2
# SWEDEN             10
# SWITZERLAND         2
# TANZANIA            3
# THE NETHERLANDS     4
# Name: Foreign Gift Amount, dtype: int64
#
# Country of Giftor
# BANGLADESH         4228589
# SWEDEN             4007552
# TANZANIA           2776447
# SWITZERLAND        2000000
# ENGLAND            1950666
# GUERNSEY           1500000
# FINLAND            1008384
# BERMUDA             900000
# KOREA               862787
# SINGAPORE           805000
# THE NETHERLANDS     725670
# ISRAEL              623655
# RWANDA              284135
# JAPAN               265970
# FRANCE              250383
# Name: Foreign Gift Amount, dtype: int64
#
# Country of Giftor
# SWITZERLAND        1000000.000000
# TANZANIA            925482.333333
# BERMUDA             900000.000000
# GUERNSEY            500000.000000
# BANGLADESH          422858.900000
# SINGAPORE           402500.000000
# SWEDEN              400755.200000
# RWANDA              284135.000000
# JAPAN               265970.000000
# THE NETHERLANDS     181417.500000
# FINLAND             144054.857143
# KOREA               143797.833333
# ENGLAND              62924.709677
# ISRAEL               51971.250000
# FRANCE               50076.600000
# Name: Foreign Gift Amount, dtype: float64
#
# 4885559.8532235
#
# 4813705.8333324995

# %%
sum((422858.900000, 402500.000000, 62924.709677))
# Out:
# 888283.609677
